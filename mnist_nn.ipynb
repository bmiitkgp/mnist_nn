# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv2D, MaxPool2D
from keras.utils import np_utils

# %%
X_train = x_train.reshape(60000, 784)
X_test = x_test.reshape(10000,784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /=255
X_test /=255

n_classes = 10

Y_train = np_utils.to_categorical(y_train, n_classes)
Y_test = np_utils.to_categorical(y_test, n_classes)

# %%
model = Sequential()

model.add(Dense(100,activation='relu', input_shape=(784,)))

model.add(Dense(10,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 100)               78500
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

model.fit(X_train, Y_train, batch_size=128, epochs=10, validation_data=(X_test, Y_test))
# Out:
# Epoch 1/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3779 - accuracy: 0.8966 - val_loss: 0.2015 - val_accuracy: 0.9402
# Epoch 2/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1729 - accuracy: 0.9509 - val_loss: 0.1576 - val_accuracy: 0.9540
# Epoch 3/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1261 - accuracy: 0.9646 - val_loss: 0.1172 - val_accuracy: 0.9658
# Epoch 4/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.1010 - accuracy: 0.9707 - val_loss: 0.1050 - val_accuracy: 0.9701
# Epoch 5/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0831 - accuracy: 0.9762 - val_loss: 0.0952 - val_accuracy: 0.9727
# Epoch 6/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0698 - accuracy: 0.9798 - val_loss: 0.0866 - val_accuracy: 0.9731
# Epoch 7/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0602 - accuracy: 0.9825 - val_loss: 0.0864 - val_accuracy: 0.9734
# Epoch 8/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0517 - accuracy: 0.9851 - val_loss: 0.0847 - val_accuracy: 0.9742
# Epoch 9/10
# 469/469 [==============================] - 2s 3ms/step - loss: 0.0444 - accuracy: 0.9874 - val_loss: 0.0804 - val_accuracy: 0.9754
# Epoch 10/10
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0388 - accuracy: 0.9890 - val_loss: 0.0843 - val_accuracy: 0.9736

# %%
model.evaluate(X_test,Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0843 - accuracy: 0.9736
# [0.08427856117486954, 0.9735999703407288]
